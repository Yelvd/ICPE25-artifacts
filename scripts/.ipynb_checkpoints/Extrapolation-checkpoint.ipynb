# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
eff = lambda n : 1 / n

# %%
x = np.array([1, 2, 4, 8, 16, 32, 64, 128])

plt.plot(x, eff(x))
plt.xlabel("Nodes")
plt.ylabel("efficiancy")
plt.show()
